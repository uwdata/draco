# %% [markdown]
# # Learn with SVM
#
# Use a linear SVM to learn weights for draco.

# %%
from draco.learn import linear

# %%
linear.main()
# Out:
# Train score:  0.9672977624784854
# Dev score:  0.9558232931726908
